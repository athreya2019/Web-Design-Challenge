# %%
import pandas as pd

# %%
# read csv data into dataframe
df = pd.read_csv('./citydata/cities.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0  tuktoyaktuk          75      CA  1569472689        81  37.40  69.44
# 1       avarua          85      CK  1569472690        83  77.00 -21.21
# 2      rikitea           0      PF  1569472690        71  71.65 -23.12
# 3      ushuaia          40      AR  1569472690        56  42.80 -54.81
# 4      mataura         100      NZ  1569472690        89  48.00 -46.19
#
#       Lng  Wind Speed
# 0 -133.03       13.87
# 1 -159.78       11.41
# 2 -134.97        8.99
# 3  -68.31       17.22
# 4  168.86       18.99

# %%
# convert dataframe to html ouput and display
html_out=df.to_html()
html_out
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Cloudiness</th>\n      <th>Country</th>\n      <th>Date</th>\n      <th>Humidity</th>\n      <th>Temp</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Wind Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>tuktoyaktuk</td>\n      <td>75</td>\n      <td>CA</td>\n      <td>1569472689</td>\n      <td>81</td>\n      <td>37.40</td>\n      <td>69.44</td>\n      <td>-133.03</td>\n      <td>13.87</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>avarua</td>\n      <td>85</td>\n      <td>CK</td>\n      <td>1569472690</td>\n      <td>83</td>\n      <td>77.00</td>\n      <td>-21.21</td>\n      <td>-159.78</td>\n      <td>11.41</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>rikitea</td>\n      <td>0</td>\n      <td>PF</td>\n      <td>1569472690</td>\n      <td>71</td>\n      <td>71.65</td>\n      <td>-23.12</t
# ...

# %%
# save datafrane to html
df.to_html('citydata.html')
